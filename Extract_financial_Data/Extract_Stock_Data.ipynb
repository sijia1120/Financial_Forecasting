# %% [markdown]
# # Extracting and Visualizing Stock Data

# %% [markdown]
# ## Description
# In this topic, you will extract some stock data and display these data in a graph.
#
# The library used in this modulue is "yfinance"

# %%
# import library
import yfinance as yf
import pandas as pd
import requests
import plotly.graph_objects as go

from plotly.subplots import make_subplots
from bs4 import BeautifulSoup

# %% [markdown]
# ## 1. Use yfinance to Extract Stock Data
# 1. Use the  **Ticker** function enter the ticker symbol of the stock we want to extract data to create a ticker object. The stock is Tesla and its ticker symbol is TSLA

# %%
tesla =yf.Ticker("TSLA")
gmestop = yf.Ticker("GME") # The stock is Gamestop and its ticker symbol is GME

# %% [markdown]
# Using the ticker object and function **history** to extract stock information and save it in a dataframe named **tesla_data**. Set the period parameter to **max** so we get information for the maximum amount of time

# %%
tesla_data = tesla.history(period="max")
gmestop_data =gmestop.history(period="max")

# %% [markdown]
# **Reset the index** using the reset_index(inplace= True) function on the tesla_data DataFrame and display the first five rows of the tesla_data using. the **head** function

# %%
#tesla_data.reset_index(inplace = True)
#tesla_data.head()
tesla_data.info
# Out:
# <bound method DataFrame.info of       index       Date        Open         High         Low       Close  \
# 0         0 2010-06-29    3.800000     5.000000    3.508000    4.778000
# 1         1 2010-06-30    5.158000     6.084000    4.660000    4.766000
# 2         2 2010-07-01    5.000000     5.184000    4.054000    4.392000
# 3         3 2010-07-02    4.600000     4.620000    3.742000    3.840000
# 4         4 2010-07-06    4.000000     4.000000    3.166000    3.222000
# ...     ...        ...         ...          ...         ...         ...
# 2977   2977 2022-04-26  995.429993  1000.000000  875.000000  876.419983
# 2978   2978 2022-04-27  898.580017   918.000000  877.359985  881.510010
# 2979   2979 2022-04-28  899.979980   900.000000  821.700012  877.510010
# 2980   2980 2022-04-29  902.250000   934.400024  870.000000  870.760010
# 2981   2981 2022-05-02  860.770020   906.359924  848.500000  902.940002
#
#         Volume  Dividends  Stock Splits
# 0     93831500          0           0.0
# 1     85935500          0           0.0
# 2     41094000          0           0.0
# 3     25699000          0           0.0
# 4     34334500          0           0.0
# ...        ...        ...           ...
# 2977  45377900          0           0.0
# 2978  25652100          0           0.0
# 2979  41649500          0           0.0
# 2980  29313400          0           0.0
# 2981  24693639          0           0.0
#
# [2982 rows x 9 columns]>

# %% [markdown]
# ### Displaying information on selected stock
# Display all the Financial data related to the company by using **info**. It will display all the information regarding the company including its Sector, No. of Employees, Business Summary, etc.

# %%
pfizer = yf.Ticker('PFE')
pfizer.info
# Out:
# {'zip': '10017',
#  'sector': 'Healthcare',
#  'fullTimeEmployees': 79000,
#  'longBusinessSummary': "Pfizer Inc. discovers, develops, manufactures, markets, distributes, and sells biopharmaceutical products worldwide. It offers medicines and vaccines in various therapeutic areas, including cardiovascular metabolic and women's health under the Premarin family and Eliquis brands; biologics, small molecules, immunotherapies, and biosimilars under the Ibrance, Xtandi, Sutent, Inlyta, Retacrit, Lorbrena, and Braftovi brands; and sterile injectable and anti-infective medicines, and oral COVID-19 treatment under the Sulperazon, Medrol, Zavicefta, Zithromax, Vfend, Panzyga, and Paxlovid brands. The company also provides medicines and vaccines in various therapeutic areas, such as pneumococcal disease, meningococcal disease, tick-borne encephalitis, and COVID-19 under the Comirnaty/BNT162b2, Nimenrix, FSME/IMMUN-TicoVac, Trumenba, and the Prevnar family brands; biosimilars for chronic immune and inflammatory diseases under the Xeljanz, Enbrel, Inflectra, Eucrisa/Staquis, and Cibinqo brands; and amyloidosis, hemophilia, and endocrine diseases under the Vyndaqel/Vyndamax, BeneFIX, and Genotropin brands. In addition, the company is involved in the contract manufacturing business. It serves wholesalers, retailers, hospitals, clinics, government agencies, pharmacies, and individual provider offices, as well as disease control and prevention centers. The company has collaboration agreements with Bristol-Myers Squibb Company; Astellas Pharma US, Inc.; Myovant Sciences Ltd.; Akcea Therapeutics, Inc; Merck KGaA; Valneva SE; BioNTech SE; and Arvinas, Inc. Pfizer Inc. was founded in 1849 and is headquartered in New York, New York.",
#  'city': 'New York',
#  'phone': '212 733 2323',
#  'state': 'NY',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.pfizer.com',
#  'maxAge': 1,
#  'address1': '235 East 42nd Street',
#  'industry': 'Drug Manufacturers—General',
#  'ebitdaMargins': 0.39303002,
#  'profitMargins': 0.27038,
#  'grossMargins': 0.62281,
#  'operatingCashflow': 32579999744,
#  'revenueGrowth': 1.068,
#  'operatingMargins': 0.33025002,
#  'ebitda': 31949000704,
#  'targetLowPrice': 49,
#  'recommendationKey': 'buy',
#  'grossProfits': 50627000000,
#  'freeCashflow': 30855249920,
#  'targetMedianPrice': 59.5,
#  'currentPrice': 48.34,
#  'earningsGrowth': 2.911,
#  'currentRatio': 1.399,
#  'returnOnAssets': 0.09996,
#  'numberOfAnalystOpinions': 23,
#  'targetMeanPrice': 60.29,
#  'debtToEquity': 53.438,
#  'returnOnEquity': 0.31870002,
#  'targetHighPrice': 76,
#  'totalCash': 31072999424,
#  'totalDebt': 41394999296,
#  'totalRevenue': 81288003584,
#  'totalCashPerShare': 5.526,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 14.513,
#  'quickRatio': 1.097,
#  'recommendationMean': 2.3,
#  'exchange': 'NYQ',
#  'shortName': 'Pfizer, Inc.',
#  'longName': 'Pfizer Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'PFE',
#  'messageBoardId': 'finmb_162270',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 3.525,
#  'beta3Year': None,
#  'enterpriseToEbitda': 8.968,
#  '52WeekChange': 0.23198593,
#  'morningStarRiskRating': None,
#  'forwardEps': 49.99,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 5647770112,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 13.737,
#  'sharesShort': 62649844,
#  'sharesPercentSharesOut': 0.0111,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.68293,
#  'netIncomeToCommon': 22413000704,
#  'trailingEps': 3.854,
#  'lastDividendValue': 0.4,
#  'SandP52WeekChange': -0.014484823,
#  'priceToBook': 3.5189633,
#  'heldPercentInsiders': 0.0004,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1640908800,
#  'shortRatio': 2.24,
#  'sharesShortPreviousMonthDate': 1647302400,
#  'floatShares': 5617441957,
#  'beta': 0.721568,
#  'enterpriseValue': 286521622528,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1605571200,
#  'lastSplitFactor': '1054:1000',
#  'legalType': None,
#  'lastDividendDate': 1643241600,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 3.011,
#  'priceToSalesTrailing12Months': 3.3585916,
#  'dateShortInterest': 1649894400,
#  'pegRatio': -8.57,
#  'ytdReturn': None,
#  'forwardPE': 0.9669934,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0111,
#  'sharesShortPriorMonth': 61175144,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 49.07,
#  'regularMarketOpen': 47.68,
#  'twoHundredDayAverage': 49.26695,
#  'trailingAnnualDividendYield': 0.03179132,
#  'payoutRatio': 0.3969,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 48.76,
#  'navPrice': None,
#  'averageDailyVolume10Day': 25164780,
#  'regularMarketPreviousClose': 49.07,
#  'fiftyDayAverage': 50.6738,
#  'trailingAnnualDividendRate': 1.56,
#  'open': 47.68,
#  'toCurrency': None,
#  'averageVolume10days': 25164780,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 1.6,
#  'exDividendDate': 1652313600,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 47.46,
#  'currency': 'USD',
#  'trailingPE': 12.542812,
#  'regularMarketVolume': 36215538,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 273013211136,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 29596931,
#  'dayLow': 47.46,
#  'ask': 48.3,
#  'askSize': 1800,
#  'volume': 36215538,
#  'fiftyTwoWeekHigh': 61.71,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 3.64,
#  'fiftyTwoWeekLow': 37.96,
#  'bid': 48.25,
#  'tradeable': False,
#  'dividendYield': 0.0326,
#  'bidSize': 800,
#  'dayHigh': 48.76,
#  'regularMarketPrice': 48.34,
#  'preMarketPrice': 47.64,
#  'logo_url': 'https://logo.clearbit.com/pfizer.com'}

# %% [markdown]
# ### Downloading the stock data
# Using the **'history'** function.
# (1) set a specific time period by passing the argument like **(start="2020-01-01", end="2020-07-21")**
# (2) set period to max, argument = **(period ="max")**

# %%
pfizer_data = pfizer.history(start= "2020-01-01", end = "2020-07-21")
pfizer_data.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2020-01-02  34.214142  34.257669  33.848493  34.074844  16514072        0.0
# 2020-01-03  33.709189  34.161895  33.665659  33.892014  14922848        0.0
# 2020-01-06  33.796256  33.952964  33.691787  33.848492  15771951        0.0
# 2020-01-07  34.057431  34.066137  33.674372  33.735313  20108107        0.0
# 2020-01-08  33.744023  34.144493  33.735318  34.005199  16403507        0.0
#
#             Stock Splits
# Date
# 2020-01-02             0
# 2020-01-03             0
# 2020-01-06             0
# 2020-01-07             0
# 2020-01-08             0

# %% [markdown]
# ### Display relevant information
# Financial Data Analyst requires the details about the Dividends and Splits the company has given to its shareholders. With the **actions** function of YFinance, we can download this.
#
# (1) stock.actions ## Dividends and Stock Splits
#
# (2) stock.splits
#
# (3) stock.dividends

# %%
pfizer.actions
pfizer.splits
pfizer.dividends
# Out:
# Date
# 2020-01-30    0.360531
# 2020-05-07    0.360531
# Name: Dividends, dtype: float64

# %% [markdown]
# ### Recommendation for buying and selling
# Recommendations for buying or selling a company’s stock is provided by different Finacial Firms. In order to analyze the stock price, we must know what these firms recommend. To analyze the recommendations we can use the **recommendations** function.

# %%
pfizer.recommendations
# Out:
#                                   Firm      To Grade From Grade Action
# Date
# 2012-03-27 06:10:00      Goldman Sachs           Buy              main
# 2012-04-02 05:52:00          Citigroup       Neutral              main
# 2012-04-09 16:25:00          ISI Group           Buy              init
# 2012-07-13 06:54:00          Jefferies           Buy              main
# 2012-07-18 06:04:00     Morgan Stanley    Overweight              main
# ...                                ...           ...        ...    ...
# 2021-12-17 12:46:19      Goldman Sachs       Neutral              init
# 2022-01-05 12:08:41  B of A Securities           Buy    Neutral     up
# 2022-01-07 16:09:38        Wells Fargo    Overweight              main
# 2022-02-10 13:59:24     Morgan Stanley  Equal-Weight              main
# 2022-04-05 11:30:36          Citigroup       Neutral              main
#
# [157 rows x 4 columns]

# %% [markdown]
# ### Calender
# **calendar** function can be used to know about the earnings and revenue of the company.

# %%
pfizer.calendar
type(pfizer.calendar)
# the type of the calendar is "pandas.core.frame.DataFrame"
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### ISIN number
# For every company listed on the stock market, there is a unique ISIN(International Securities Identification Number) no. we can retrieve this number using YFinance **isin** function.

# %%
pfizer.isin
# Out:
# 'US7170811035'

# %% [markdown]
# ### Option Expiry Date of the stock
# During option trading we must know about the option expiry date, using the **options** function we can retrieve the Option Expiry Date of that particular stock.

# %%
pfizer.options

# %% [markdown]
# ### Sustainability
# To know the sustainability of the stock there is a predefined function named **sustainability** which can be used to display data about the sustainability of the company.

# %%
pfizer.sustainability
# Out:
#                                  Value
# 2022-2
# palmOil                          False
# controversialWeapons             False
# gambling                         False
# socialScore                      13.54
# nuclear                          False
# furLeather                       False
# alcoholic                        False
# gmo                              False
# catholic                          True
# socialPercentile                  None
# peerCount                           83
# governanceScore                   9.53
# environmentPercentile             None
# animalTesting                     True
# tobacco                          False
# totalEsg                          24.6
# highestControversy                   3
# esgPerformance                AVG_PERF
# coal                             False
# pesticides                       False
# adult                            False
# percentile                       40.63
# peerGroup              Pharmaceuticals
# smallArms                        False
# environmentScore                  1.52
# governancePercentile              None
# militaryContract                 False
